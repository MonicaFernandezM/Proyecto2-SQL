# %%
import pandas as pd 
import numpy as np
import data_utils as du

# %%
#Instalar si se necesita
#pip install scikit-learn

# %%
#cargando tablas
df_rock = pd.read_csv("UltimateClassicRock.csv")
df_spotify = pd.read_csv("archive/track_data_final.csv",  encoding='latin1')
df_billboard = pd.read_csv("Full_Billboard.csv", encoding='latin1')

# %% [markdown]
# #### Primera Vision de las tablas

# %%
#Viendo los valores de la tabla rock
df_rock.head()
# Out:
#                     Track      Artist       Album  Year Duration  \
# 0      Play A Simple Song  38 Special  38 Special  1977     3:13
# 1             Four Wheels  38 Special  38 Special  1977     4:43
# 2                Fly Away  38 Special  38 Special  1977     5:13
# 3          Tell Everybody  38 Special  38 Special  1977     4:09
# 4  Just Wanna Rock & Roll  38 Special  38 Special  1977     5:57
#
#    Time_Signature  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0               4         0.521   0.367    0   -13.866     1       0.0278
# 1               4         0.535   0.710    2   -12.287     1       0.0428
# 2               4         0.563   0.563    2   -10.781     1       0.0263
# 3               4         0.638   0.694   11   -10.206     0       0.0310
# 4               4         0.388   0.701    2    -9.984     1       0.0360
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Popularity
# ...

# %%
#Viendo los valores de la spotify 
du.show_total_info(df_spotify, 5)
# Out:
# HEAD:
#                  track_id                             track_name  \
# 0  6pymOcrCnMuCWdgGVTvUgP                                      3
# 1  2lWc1iJlz2NVcStV5fbtPG                                 Clouds
# 2  1msEuwSBneBKpVCZQcFTsU  Forever & Always (Taylorâs Version)
# 3  7bcy34fBT2ap1L4bfPsl9q              I Didn't Change My Number
# 4  0GLfodYacy3BJE7AI3A8en                               Man Down
#
#    track_number  track_popularity  track_duration_ms  explicit  \
# 0            57                61             213173     False
# 1             1                67             158760     False
# 2            11                63             225328     False
# 3             2                72             158463      True
# 4             7                57             267013     False
#
#       artist_name  artist_popularity  artist_followers      artist_genres  \
# 0  Britney Spears               80.0        17755451.0            ['pop']
# ...

# %%
#Viendo los valores de la billboard 
df_billboard.head()
# Out:
#   No.              Title      Artist(s)  Year
# 0   1   Prisoner of Love     Perry Como  1946
# 1   2    To Each His Own    Eddy Howard  1946
# 2   3          The Gypsy      Ink Spots  1946
# 3   4  Five Minutes More  Frank Sinatra  1946
# 4   5  Rumors Are Flying  Frankie Carle  1946

# %% [markdown]
# #### Unificando nombre de las columnas y Eliminacion

# %%
#Viendo los nombres de columnas de la tabla rock
df_rock.columns
# Out:
# Index(['Track', 'Artist', 'Album', 'Year', 'Duration', 'Time_Signature',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Popularity'],
#       dtype='object')

# %%
#Elimininamos columnas que no vamos a utilizar en rock
df_rock = df_rock.drop(columns = ['Duration', 'Time_Signature',
       'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo'])

# %%
#Viendo los nombres de columnas de la tabla spotify
df_spotify.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'track_duration_ms', 'explicit', 'artist_name', 'artist_popularity',
#        'artist_followers', 'artist_genres', 'album_id', 'album_name',
#        'album_release_date', 'album_total_tracks', 'album_type'],
#       dtype='object')

# %%
#Eliminamos columnas de df_spotify que no vamos a utilizar
df_spotify = df_spotify.drop(columns = ['track_id', 'track_number','track_duration_ms', 'explicit', 
                                        'album_total_tracks', 'album_type'])

# %%
#pasando todo a minusculas para unificar nombres de columnas
df_rock.columns = df_rock.columns.str.lower().str.strip().str.replace(" ", "_")
df_billboard.columns = df_billboard.columns.str.lower().str.strip().str.replace(" ", "_")

# %%
#verificamos cambios en el database rock
df_rock.head()
# Out:
#                     track      artist       album  year  popularity
# 0      Play A Simple Song  38 Special  38 Special  1977          16
# 1             Four Wheels  38 Special  38 Special  1977          10
# 2                Fly Away  38 Special  38 Special  1977          13
# 3          Tell Everybody  38 Special  38 Special  1977          10
# 4  Just Wanna Rock & Roll  38 Special  38 Special  1977          11

# %%
#modificamos nombre de la tabla spotify 
df_spotify = df_spotify.rename(columns= {'track_popularity': 'popularity', 'album_release_date' : 'year', 
                    'artist_genres' : 'genre_name'})

# %%
#modificamos nombre de la tabla rock
df_rock = df_rock.rename(columns= {'track': 'track_name', 'artist' : 'artist_name', 
                    'album' : 'album_name'})

# %%
#modificamos nombre de la tabla billboard 
df_billboard = df_billboard.rename(columns={'title': 'track_name',
                                            'artist(s)': 'artist_name',
                                            'no.': 'rank'})

# %%
#verificamos los cambios
df_spotify.head()
# Out:
#                               track_name  popularity     artist_name  \
# 0                                      3          61  Britney Spears
# 1                                 Clouds          67           BUNT.
# 2  Forever & Always (Taylorâs Version)          63    Taylor Swift
# 3              I Didn't Change My Number          72   Billie Eilish
# 4                               Man Down          57         Rihanna
#
#    artist_popularity  artist_followers         genre_name  \
# 0               80.0        17755451.0            ['pop']
# 1               69.0          293734.0  ['stutter house']
# 2              100.0       145396321.0                 []
# 3               90.0       118692183.0                 []
# 4               90.0        68997177.0                 []
#
#                  album_id                   album_name        year
# 0  325wcm5wMnlfjmKZ8PXIIn       The Singles Collection  2009-11-09
# ...

# %%
#Cambiamos la columna year en spotify para quedanos solo con el año y lo pasamos a tipo int 
df_spotify['year'] = pd.to_datetime(df_spotify['year'], errors='coerce').dt.year
df_spotify['year'] = df_spotify['year'].astype('Int64')

# %%
#creando una columna genero para la tabla rock
df_rock['genre_name'] = 'rock'
df_rock
# Out:
#                           track_name artist_name  album_name  year  \
# 0                 Play A Simple Song  38 Special  38 Special  1977
# 1                        Four Wheels  38 Special  38 Special  1977
# 2                           Fly Away  38 Special  38 Special  1977
# 3                     Tell Everybody  38 Special  38 Special  1977
# 4             Just Wanna Rock & Roll  38 Special  38 Special  1977
# ...                              ...         ...         ...   ...
# 14413                    Consumption      ZZ Top   La Futura  2012
# 14414  I Don't Wanna Lose, Lose, You      ZZ Top   La Futura  2012
# 14415            Have A Little Mercy      ZZ Top   La Futura  2012
# 14416                    Flyin' High      ZZ Top   La Futura  2012
# 14417              Heartache In Blue      ZZ Top   La Futura  2012
#
#        popularity genre_name
# 0              16       rock
# 1              10       rock
# 2              13       rock
# 3              10       rock
# ...

# %% [markdown]
# #### Limpiando nombres de canciones

# %%
#Creamos esta funcion para verificar nombres de canciones
def clean_artist_name(s):
    return (
        s.str.lower()
         .str.replace(r" featuring.*", "", regex=True)
         .str.replace(r" feat.*", "", regex=True)
         .str.replace(r"&.*", "", regex=True)
         .str.strip()
    )

# %%
#Utilizamos la funcion en las tres tablas
df_rock["artist_name"] = clean_artist_name(df_rock["artist_name"])
df_billboard["artist_name"] = clean_artist_name(df_billboard["artist_name"])
df_spotify["artist_name"] = clean_artist_name(df_spotify["artist_name"])

# %%
#viendo valores nulos en la 
du.mis_dupl(df_rock)
# Out:
# Missing values:
# track_name     0
# artist_name    0
# album_name     0
# year           0
# popularity     0
# genre_name     0
# dtype: int64
# Duplicates values:
# 0

# %%
#viendo la cantidad de nulos en year que son un 2%
du.mis_dupl(df_spotify)
# Out:
# Missing values:
# track_name             2
# popularity             0
# artist_name            4
# artist_popularity      4
# artist_followers       4
# genre_name             4
# album_id               0
# album_name             2
# year                 201
# dtype: int64
# Duplicates values:
# 0

# %%
#Eliminando filas de year y artist_name con datos faltantes en la tabla spotify
df_spotify = df_spotify.dropna(subset=['year', 'artist_name'])

# %%
#los años esten correctos en todas las tablas
df_rock = df_rock[df_rock['year'].between(1950, 2025)]
df_spotify = df_spotify[df_spotify['year'].between(1950, 2025)]
df_billboard = df_billboard[df_billboard['year'].between(1950, 2025)]

# %%
billboard_artists = set(df_billboard["artist_name"])
rock_artists = set(df_rock["artist_name"])

only_in_billboard = billboard_artists - rock_artists

len(only_in_billboard)
# Out:
# 2662

# %% [markdown]
# #### Pasando tablas limpias al CSV

# %%
df_spotify.to_csv("spotify_clean.csv", index=False, encoding="utf-8-sig")

# %%
df_rock.to_csv("rock_clean.csv", index=False, encoding="utf-8-sig")

# %%
df_billboard.to_csv("billboard_clean.csv", index=False, encoding="utf-8")

# %% [markdown]
# ### Python a SQL

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input

# %%
bd = "proyecto_sql_rock"
connection_string = 'mysql+pymysql://root:' + 'Sg30rg3rrm4rt1n!l' + '@localhost/'+bd
engine = create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/proyecto_sql_rock)

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',
                        user='root',
                        passwd='Sg30rg3rrm4rt1n!l')

# %%
cursor = conn.cursor()

cursor

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SHOW TABLES;"))
    for row in result:
        print(row)

# %%
df_rock.to_sql(
    "rock_clean",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 14418

# %%
df_spotify.to_sql(
    "spotify_clean",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 8573

# %%
df_billboard.to_sql(
    "billboard_clean",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 6632

# %%
from sqlalchemy import text

with engine.connect() as conn:
    print(conn.execute(text("SHOW TABLES;")).fetchall())
# Out:
# [('billboard_clean',), ('rock_clean',), ('spotify_clean',)]
